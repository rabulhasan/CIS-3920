# %% [markdown]
# Ans 4: i  think xdfsdf
# s
# sdf

# %%
# load some library

library (MASS)   # tons of stuff in this library
library (ISLR)   # data associates with ISLR book
# Out:
# Warning message:
# "package 'ISLR' was built under R version 3.6.3"

# %%
head(Boston)
# Out:
#   crim    zn indus chas nox   rm    age  dis    rad tax ptratio black  lstat
# 1 0.00632 18 2.31  0    0.538 6.575 65.2 4.0900 1   296 15.3    396.90 4.98
# 2 0.02731  0 7.07  0    0.469 6.421 78.9 4.9671 2   242 17.8    396.90 9.14
# 3 0.02729  0 7.07  0    0.469 7.185 61.1 4.9671 2   242 17.8    392.83 4.03
# 4 0.03237  0 2.18  0    0.458 6.998 45.8 6.0622 3   222 18.7    394.63 2.94
# 5 0.06905  0 2.18  0    0.458 7.147 54.2 6.0622 3   222 18.7    396.90 5.33
# 6 0.02985  0 2.18  0    0.458 6.430 58.7 6.0622 3   222 18.7    394.12 5.21
#   medv
# 1 24.0
# 2 21.6
# 3 34.7
# 4 33.4
# 5 36.2
# 6 28.7

# %%
fix(Boston )     # excel style view

# %%
# Simple Linear regression with Boston Dataset
names(Boston )   # name of columns/variables/predictors
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
# load the columns to memeory in order to call them directly 
attach(Boston)

# %%
# the lm(), or “linear model,” function can be used to create a simple regression model.
# It can carry out regression, and analysis of variance and covariance
# The basic syntax is lm(y∼x,data), where y is the response, x is the predictor, and 
# data is the data set in which these two variables are kept
# ***********************************************************
# Run a simple linear regression with one predictor variable
# 'medv' as the response and 'lstat' as the predictor
lm.fit = lm(medv∼lstat,data=Boston )

# %%
# get some basic info from this Simple linear regression
#  y = b0 + b1x ;  b0 = intercept   b1 = slope/coefficent of x
lm.fit
# Out:
# Call:
# lm(formula = medv ~ lstat, data = Boston)
#
# Coefficients:
# (Intercept)        lstat
#       34.55        -0.95

# %%
# more details about im.fit
summary (lm.fit)
# Out:
# Call:
# lm(formula = medv ~ lstat, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.168  -3.990  -1.318   2.034  24.500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.55384    0.56263   61.41   <2e-16 ***
# lstat       -0.95005    0.03873  -24.53   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.216 on 504 degrees of freedom
# Multiple R-squared:  0.5441,	Adjusted R-squared:  0.5432
# F-statistic: 601.6 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
# We can use the names() function in order to find out what other pieces
# names() of information are stored in lm.fit
names(lm.fit )
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %%
# we could access those variables by using traditional way $
lm.fit$coefficients
# Out:
# (Intercept)       lstat
#  34.5538409  -0.9500494

# %%
# or it is safer to use the extractor functions 
# like coef() to access them
coef(lm.fit)
# Out:
# (Intercept)       lstat
#  34.5538409  -0.9500494

# %%
# In order to obtain a confidence interval for the coefficient estimates, we can
# use the confint() command
confint (lm.fit)
# Out:
#             2.5 %     97.5 %
# (Intercept) 33.448457 35.6592247
# lstat       -1.026148 -0.8739505

# %%
# The predict() function can be used to produce confidence intervals and
# prediction intervals for the prediction of medv for a given value of lstat.
# interval = confidence
predict(lm.fit,data.frame(lstat=c(5 ,10 ,15) ),interval ="confidence")
# Out:
#   fit      lwr      upr
# 1 29.80359 29.00741 30.59978
# 2 25.05335 24.47413 25.63256
# 3 20.30310 19.73159 20.87461

# %% [markdown]
# For instance, the 95% confidence interval associated with a lstat value of
# 10 is (24.47, 25.63)

# %%
# interval = predition
predict (lm.fit,data.frame(lstat=c(5 ,10 ,15) ),interval ="prediction")
# Out:
#   fit      lwr       upr
# 1 29.80359 17.565675 42.04151
# 2 25.05335 12.827626 37.27907
# 3 20.30310  8.077742 32.52846

# %% [markdown]
# The 95% prediction interval is (12.828, 37.28).
#
# As expected, the confidence and prediction intervals are centered around the
# same point (a predicted value of 25.05 for medv when lstat equals 10)

# %%
# Graph - visual 
# We will now plot medv and lstat along with the least squares regression
# line using the plot() and abline() functions
plot(lstat,medv)
abline (lm.fit)
# Out:
# plot without title

# %% [markdown]
# There is some evidence for non-linearity in the relationship between lstat
# and medv.

# %% [raw]
# The abline() function can be used to draw any line, not just the least squares regression line.
# To draw a line with intercept a and slope b, we type abline(a,b).
#
# Below we experiment with some additional settings for plotting lines and points.
# The lwd=3 command causes the width of the regression line to be increased by a factor of 3

# %%
plot(lstat,medv)
# abline (lm.fit,lwd =3)   # regression line thickness
abline (lm.fit,lwd =3, col ="red ")
# Out:
# plot without title

# %%
plot(lstat,medv,col ="red")  # observe data in red color
# Out:
# plot without title

# %%
# We can also use the pch option to create different plotting symbols.
plot(lstat,medv,pch=20)
# Out:
# plot without title

# %%
plot(lstat ,medv ,pch ="@")    # custom symbol
# Out:
# plot without title

# %%
plot (1:20 ,1:20, pch =1:20)
# Out:
# plot without title

# %%
# x <- 1:10; y <- x^2
# plot(x, y)
# identify(x, y)

# %% [raw]
# Exact collinearity is an extreme example of collinearity, which occurs in multiple regression when
# predictor variables are highly correlated. Collinearity is often called multicollinearity,
# since it is a phenomenon that really only occurs during multiple regression.

# %%
# View four graphs in one window
# We can achieve this by using the par() function, which tells R to split the display screen into separate 
# panels so that multiple plots can be viewed simultaneously.

par(mfrow =c(2,2))  # divides the plotting region into a 2 × 2 grid of panels
plot(lm.fit)
# Out:
# Plot with title ""

# %%
# compute residuals from a linear regression fit using the residuals() function
plot(predict (lm.fit), residuals (lm.fit))
# Out:
# plot without title

# %%
# The function rstudent() will return the studentized residuals
plot(predict (lm.fit), rstudent (lm.fit))
# Out:
# plot without title

# %%
par(mfrow =c(2,1))  # divides the plotting region into a 2 × 2 grid of panels
plot(predict (lm.fit), residuals (lm.fit))
plot(predict (lm.fit), rstudent (lm.fit))
# Out:
# plot without title

# %% [markdown]
# On the basis of the residual plots, there is some evidence of non-linearity

# %%
plot(hatvalues (lm.fit ))
which.max (hatvalues (lm.fit))
# head(hatvalues (lm.fit ))
# Out:
# 375
# 375
# plot without title

# %%
# Multiple linear regression with two variables
lm.fit =lm(medv∼lstat+age ,data=Boston )

# %%
summary (lm.fit)
# Out:
# Call:
# lm(formula = medv ~ lstat + age, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.981  -3.978  -1.283   1.968  23.158
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 33.22276    0.73085  45.458  < 2e-16 ***
# lstat       -1.03207    0.04819 -21.416  < 2e-16 ***
# age          0.03454    0.01223   2.826  0.00491 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.173 on 503 degrees of freedom
# Multiple R-squared:  0.5513,	Adjusted R-squared:  0.5495
# F-statistic:   309 on 2 and 503 DF,  p-value: < 2.2e-16

# %%
# including all variables 
lm.fit =lm(medv∼.,data=Boston )
summary (lm.fit)
# Out:
# Call:
# lm(formula = medv ~ ., data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.595  -2.730  -0.518   1.777  26.199
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.646e+01  5.103e+00   7.144 3.28e-12 ***
# crim        -1.080e-01  3.286e-02  -3.287 0.001087 **
# zn           4.642e-02  1.373e-02   3.382 0.000778 ***
# indus        2.056e-02  6.150e-02   0.334 0.738288
# chas         2.687e+00  8.616e-01   3.118 0.001925 **
# nox         -1.777e+01  3.820e+00  -4.651 4.25e-06 ***
# rm           3.810e+00  4.179e-01   9.116  < 2e-16 ***
# age          6.922e-04  1.321e-02   0.052 0.958229
# dis         -1.476e+00  1.995e-01  -7.398 6.01e-13 ***
# rad          3.060e-01  6.635e-02   4.613 5.07e-06 ***
# tax         -1.233e-02  3.760e-03  -3.280 0.001112 **
# ptratio     -9.527e-01  1.308e-01  -7.283 1.31e-12 ***
# black        9.312e-03  2.686e-03   3.467 0.000573 ***
# ...
